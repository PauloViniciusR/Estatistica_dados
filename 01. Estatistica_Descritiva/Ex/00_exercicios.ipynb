# %% [markdown]
# # Exercício 1
#
# A seguinte base de dados apresenta o histórico de cotações para uma determinada ação ao longo dos dias úteis de um mês. Faça:
#
# - `describe` do Pandas
# - encontre a moda, assimetria e curtose
# - faça o gráfico de histograma e boxplot combinados

# %%
import pandas as pd

DADOS = "../dados/acao.csv"

df_acao = pd.read_csv(DADOS)

df_acao
# Out:
#     preco
# 0    18.7
# 1    18.3
# 2    18.4
# 3    18.7
# 4    18.8
# 5    18.8
# 6    19.1
# 7    18.9
# 8    19.1
# 9    19.9
# 10   18.5
# 11   18.5
# 12   18.1
# 13   17.9
# 14   18.2
# 15   18.3
# 16   18.1
# 17   18.8
# 18   17.5
# 19   16.9

# %%
df_acao.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   preco   20 non-null     float64
# dtypes: float64(1)
# memory usage: 292.0 bytes

# %%
df_acao.describe()
# Out:
#            preco
# count  20.000000
# mean   18.475000
# std     0.632352
# min    16.900000
# 25%    18.175000
# 50%    18.500000
# 75%    18.800000
# max    19.900000

# %%
df_acao.mode()
# Out:
#    preco
# 0   18.8

# %%
df_acao["preco"].value_counts()
# Out:
# preco
# 18.8    3
# 18.7    2
# 18.3    2
# 19.1    2
# 18.5    2
# 18.1    2
# 18.4    1
# 18.9    1
# 19.9    1
# 17.9    1
# 18.2    1
# 17.5    1
# 16.9    1
# Name: count, dtype: int64

# %%
df_acao.skew()
# Out:
# preco   -0.364691
# dtype: float64

# %%
df_acao.kurtosis()
# Out:
# preco    1.752875
# dtype: float64

# %%
from auxiliares import composicao_boxplot

composicao_boxplot(df_acao, "preco")

# %% [markdown]
# # Exercício 2
#
# A seguinte base de dados apresenta o resultado de uma raspagem de dados feita em diversos e-commerces para o preço de um fone de ouvido. Faça:
#
# - `describe` do Pandas
# - encontre a moda, assimetria e curtose
# - faça o gráfico de histograma e boxplot combinados

# %%
import pandas as pd

DADOS = "../dados/prices.csv"

df_fone = pd.read_csv(DADOS)

df
# Out:
#     Price
# 0   189.0
# 1   195.0
# 2   199.0
# 3   189.0
# 4   197.0
# ..    ...
# 95  189.0
# 96  179.0
# 97  189.0
# 98  199.0
# 99  195.0
#
# [100 rows x 1 columns]

# %%
df_fone.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   100 non-null    float64
# dtypes: float64(1)
# memory usage: 932.0 bytes

# %%
df_fone.describe()
# Out:
#             Price
# count  100.000000
# mean   190.770000
# std     15.621052
# min    149.000000
# 25%    179.000000
# 50%    189.000000
# 75%    199.000000
# max    239.000000

# %%
df_fone.mode()
# Out:
#    Price
# 0  199.0

# %%
df_fone["Price"].value_counts()
# Out:
# Price
# 199.0    21
# 189.0    19
# 179.0    13
# 169.0     7
# 195.0     6
# 209.0     6
# 205.0     4
# 159.0     3
# 175.0     2
# 229.0     2
# 215.0     2
# 170.0     2
# 185.0     2
# 197.0     1
# 202.0     1
# 219.0     1
# 190.0     1
# 183.0     1
# 206.0     1
# 149.0     1
# 196.0     1
# 165.0     1
# 182.0     1
# 239.0     1
# Name: count, dtype: int64

# %%
df_fone.skew()
# Out:
# Price    0.089906
# dtype: float64

# %%
df_fone.kurtosis()
# Out:
# Price    0.669453
# dtype: float64

# %%
composicao_boxplot(df_fone, "Price")
