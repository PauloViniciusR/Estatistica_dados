# %% [markdown]
# ## Exercício 1

# %% [markdown]
# Considere uma cidade no norte dos Estados Unidos. Uma pesquisa foi feita para verificar o voto em um partido político específico. A base de dados é apresentada a seguir. Verifique, com um nível de significância de 5%, se a distribuição de votos na cidade depende do grupo étnico.'

# %%
import pandas as pd

DADOS = "../dados/us_city_voters.csv"

df_votos = pd.read_csv(DADOS)

df_votos
# Out:
#         group        party
# 0       white     democrat
# 1       asian   republican
# 2       white  independent
# 3       white   republican
# 4       other     democrat
# ..        ...          ...
# 995     white   republican
# 996  hispanic  independent
# 997     black  independent
# 998     white   republican
# 999     black     democrat
#
# [1000 rows x 2 columns]

# %%
df_votos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   group   1000 non-null   str
#  1   party   1000 non-null   str
# dtypes: str(2)
# memory usage: 15.8 KB

# %%
df_votos.describe()
# Out:
#         group       party
# count    1000        1000
# unique      5           3
# top     white  republican
# freq      497         417

# %%
pd.crosstab(df_votos["group"], df_votos["party"])
# Out:
# party     democrat  independent  republican
# group
# asian           21            7          32
# black           65           25          64
# hispanic       107           50          94
# other           15            8          15
# white          189           96         212

# %%
pd.crosstab(
    df_votos["group"],
    df_votos["party"], 
    margins=True,
    margins_name="Total",
    normalize="index"
).style.format("{:.1%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fd31">
#   <thead>
#     <tr>
#       <th class="index_name level0" >party</th>
#       <th id="T_5fd31_level0_col0" class="col_heading level0 col0" >democrat</th>
#       <th id="T_5fd31_level0_col1" class="col_heading level0 col1" >independent</th>
#       <th id="T_5fd31_level0_col2" class="col_heading level0 col2" >republican</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fd31_level0_row0" class="row_heading level0 row0" >asian</th>
#       <td id="T_5fd31_row0_col0" class="data row0 col0" >35.0%</td>
#       <td id="T_5fd31_row0_col1" class="data row0 col1" >11.7%</td>
#       <td id="T_5fd31_row0_col2" class="data row0 col2" >53.3%</td>
#     </tr>
#     <tr>
#       <th id="T_5fd31_level0_row1" class="row_heading level0 row1" >black</th>
#       <td id="T_5fd31_row1_col0" class="data row1 col0" >42.2%</td>
#       <td id="T_5fd31_row1_col1" class="data row1 col1" >16.2%</td>
#       <td id="T_5fd31_row1_col2" class="data row1 col2" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5fd31_level0_row2" class="row_heading level0 row2" >hispanic</th>
#       <td id="T_5fd31_row2_col0" class="data row2 col0" >42.6%</td>
#       <td id="T_5fd31_row2_col1" class="data row2 col1" >19.9%</td>
#       <td id="T_5fd31_row2_col2" class="data row2 col2" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5fd31_level0_row3" class="row_heading level0 row3" >other</th>
#       <td id="T_5fd31_row3_col0" class="data row3 col0" >39.5%</td>
#       <td id="T_5fd31_row3_col1" class="data row3 col1" >21.1%</td>
#       <td id="T_5fd31_row3_col2" class="data row3 col2" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5fd31_level0_row4" class="row_heading level0 row4" >white</th>
#       <td id="T_5fd31_row4_col0" class="data row4 col0" >38.0%</td>
#       <td id="T_5fd31_row4_col1" class="data row4 col1" >19.3%</td>
#       <td id="T_5fd31_row4_col2" class="data row4 col2" >42.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5fd31_level0_row5" class="row_heading level0 row5" >Total</th>
#       <td id="T_5fd31_row5_col0" class="data row5 col0" >39.7%</td>
#       <td id="T_5fd31_row5_col1" class="data row5 col1" >18.6%</td>
#       <td id="T_5fd31_row5_col2" class="data row5 col2" >41.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
from scipy.stats import chi2_contingency

resultado = chi2_contingency(pd.crosstab(df_votos["group"],df_votos["party"]))

resultado
# Out:
# Chi2ContingencyResult(statistic=np.float64(7.169321280162059), pvalue=np.float64(0.518479392948842), dof=8, expected_freq=array([[ 23.82 ,  11.16 ,  25.02 ],
#        [ 61.138,  28.644,  64.218],
#        [ 99.647,  46.686, 104.667],
#        [ 15.086,   7.068,  15.846],
#        [197.309,  92.442, 207.249]]))

# %%
resultado.expected_freq
# Out:
# array([[ 23.82 ,  11.16 ,  25.02 ],
#        [ 61.138,  28.644,  64.218],
#        [ 99.647,  46.686, 104.667],
#        [ 15.086,   7.068,  15.846],
#        [197.309,  92.442, 207.249]])

# %%
resultado.pvalue
# Out:
# np.float64(0.518479392948842)

# %% [markdown]
# ## Exercício 2
#
# Um analista de mercado acionário coletou os retornos mensais de duas ações que pretende indicar aos seus clientes. Calcule as estatísticas descritivas para as duas ações, incluindo o coeficiente de correlação entre os retornos.

# %%
DADOS ="../dados/acoes_retornos.csv"

df_acoes = pd.read_csv(DADOS, index_col="meses")

df_acoes
# Out:
#         acao1   acao2
# meses
# 1     -0.0212  0.2645
# 2      0.2438  0.2086
# 3      0.2296  0.1248
# 4     -0.2018  0.0209
# 5      0.1296  0.2055
# 6      0.0615  0.6260
# 7     -0.1591 -0.1490
# 8     -0.1001  0.2580
# 9     -0.0265  0.1722
# 10     0.0776  0.0199
# 11     0.0370  0.4331
# 12     0.1116  0.5482
# 13    -0.0667  0.0452
# 14    -0.0082 -0.1410
# 15     0.0119 -0.1059
# 16     0.1205  0.4074
# 17     0.0477 -0.0056
# 18     0.2814  0.1482
# 19    -0.0674  0.0753
# 20     0.0762  0.0899
# 21    -0.1111  0.0160
# 22    -0.0557  0.1805
# 23     0.1991  0.0334

# %%
df_acoes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 1 to 23
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   acao1   23 non-null     float64
#  1   acao2   23 non-null     float64
# dtypes: float64(2)
# memory usage: 500.0 bytes

# %%
df_acoes.describe()
# Out:
#            acao1      acao2
# count  23.000000  23.000000
# mean    0.035204   0.151135
# std     0.129221   0.203822
# min    -0.201800  -0.149000
# 25%    -0.061200   0.020400
# 50%     0.037000   0.124800
# 75%     0.116050   0.233300
# max     0.281400   0.626000

# %%
import seaborn as sns

sns.boxplot(data=df_acoes)
# Out:
# <Axes: >

# %%
df_acoes.corr()
# Out:
#           acao1     acao2
# acao1  1.000000  0.290819
# acao2  0.290819  1.000000

# %%
df_acoes.plot.scatter(x="acao1", y="acao2")
# Out:
# <Axes: xlabel='acao1', ylabel='acao2'>
