# %% [markdown]
# # Testes para normalidade univariada

# %% [markdown]
# ## Teste de Shapiro-Wilk

# %% [markdown]
# Teste específico para distribuições normais e pode ser aplicado para amostras de tamanho $4 \le n \le 5000$, sendo uma alternativa ao teste K-S para normalidade de pequenas amostras.

# %% [markdown]
# O teste de Shapiro-Wilk assume as seguintes hipóteses:
#
# - $H_0$: a amostra provém de uma população com distribuição normal
# - $H_1$: a amostra não provém de uma população com distribuição normal

# %% [markdown]
# Exemplo: Considere uma empresa que produz aviões. A base a seguir apresenta os dados de produção mensal de aviões nos últimos 24 meses. Verifique se os dados são provenientes de uma população com distribuição normal, considerando $\alpha = 1 \%$.

# %%
import pandas as pd

DADOS_PRODUCAO_AVIOES = "../dados/aircraft.csv"

df_avioes = pd.read_csv(DADOS_PRODUCAO_AVIOES)
df_avioes.head()
# Out:
#    production
# 0          28
# 1          32
# 2          46
# 3          24
# 4          22

# %%
df_avioes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   production  24 non-null     int64
# dtypes: int64(1)
# memory usage: 324.0 bytes

# %%
df_avioes.describe()
# Out:
#        production
# count   24.000000
# mean    27.500000
# std      7.627183
# min     15.000000
# 25%     22.750000
# 50%     28.000000
# 75%     32.000000
# max     46.000000

# %%
from auxiliares import composicao_boxplot

composicao_boxplot(df_avioes, "production")

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html

# %%
from scipy.stats import shapiro

shapiro(df_avioes["production"])
# Out:
# ShapiroResult(statistic=np.float64(0.9780083233733671), pvalue=np.float64(0.8565108931130727))

# %%
estatistica, p_value = shapiro(df_avioes["production"])

# %%
estatistica
# Out:
# np.float64(0.9780083233733671)

# %%
p_value
# Out:
# np.float64(0.8565108931130727)

# %% [markdown]
# Como $pvalue > 0.01$, não rejeitamos a hipótese nula. Ao nível de confiança de 99 %, podemos concluir que a amostra é obtida de uma população com distribuição normal.

# %%
from auxiliares import analise_shapiro

analise_shapiro(df_avioes, alfa=0.01)
# Out:
# Teste de Shapiro-Wilk
# estatistica=0.978
# production segue uma distribuição normal (valor p: pvalue=0.857)
